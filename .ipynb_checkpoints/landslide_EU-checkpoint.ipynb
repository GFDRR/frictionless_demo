# %%
import json
import requests
import pandas as pd
import geopandas as gpd
import os
import rasterio
from rasterio.plot import show as Show
from rasterio import mask as mask
import pylab as plt
data = os.getenv('data')
from rasterstats import point_query
import pycountry
import shapely
from shapely import wkt
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %% [markdown]
# ### Landslide analysis of POIs for EU countries
# * import POI databases created earlier
# * query school & hospital locations based on Global Landslide Hazard Map
# * merge with ADM1 boundaries
# * plot the results

# %%
landslide_pth = data+'/energy/LS_RF_Mean_1980-2018.tif'  # ARUP landslide layer downloaded from DDH (rainfall trigge)

# %% [markdown]
# #### 1. Landslide data cropped to national borders

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))  # natural earth dataset used for country outlines
country = 'Italy'
geom = world.geometry[world.name == country].reset_index(drop=True)[0]
geom

# %%
with rasterio.open(landslide_pth) as src:
    maskData, maskTransform = mask.mask(src, [geom], crop=True, nodata=src.nodatavals[0])

# %%
plt.imshow(maskData[0,:,:], cmap = 'magma')
plt.colorbar()
plt.title('Mean annual landslide frequency (rainfall-induced)');

# %% [markdown]
# #### 1. Get subnational boundaries
# ADM1 boundaries from the geoBoundaries database.

# %%
def get_boundaries(alpha3,verbose=True):
    r = requests.get("https://www.geoboundaries.org/gbRequest.html?ISO={}&ADM=ADM1".format(alpha3))
    dlPath = r.json()[0]['gjDownloadURL']
    geoBoundary = requests.get(dlPath).json()
    gdf = gpd.GeoDataFrame.from_features(geoBoundary['features'])[['geometry','shapeName']]
    if verbose:
        print('{}: retrieved {} features'.format(alpha3, len(gdf)))
    return(gdf)

# %%
countries = ['Austria','Croatia','Greece','Slovakia','Slovenia','Italy','Montenegro','Bosnia and Herzegovina']
alpha3s = []
for country in countries:
    countries_db = pycountry.countries.get(name=country)
    alpha3s.append(countries_db.alpha_3)
alpha3s
# Out:
# ['AUT', 'HRV', 'GRC', 'SVK', 'SVN', 'ITA', 'MNE', 'BIH']

# %%
boundaries_Austria = get_boundaries('AUT')
boundaries_Croatia = get_boundaries('HRV')
boundaries_Greece = get_boundaries('GRC')
boundaries_Slovakia = get_boundaries('SVK')
boundaries_Slovenia = get_boundaries('SVN')
boundaries_Italy = get_boundaries('ITA')
# Out:
# AUT: retrieved 9 features
# HRV: retrieved 21 features
# GRC: retrieved 8 features
# SVK: retrieved 8 features
# SVN: retrieved 12 features
# ITA: retrieved 20 features

# %% [markdown]
# #### 2. Import POIs dataframe and query landslide map
# POIs for schools and hospitals created earlier.

# %%
def get_pois_with_landslide_risk(country,poi):
    pth = 'output/{}_{}.shp'.format(country,poi)
    gdf = gpd.read_file(pth)
    gdf['landslide_prob'] = point_query(gdf, landslide_pth)
    gdf.landslide_prob = gdf.landslide_prob.fillna(0) * 100
    return(gdf)

# %%
ls output
# Out:
# andorra/              croatia_school.shp   monaco_school.dbf
# andorra_school.cpg    croatia_school.shx   monaco_school.prj
# andorra_school.dbf    greece/              monaco_school.shp
# andorra_school.prj    greece_hospital.cpg  monaco_school.shx
# andorra_school.shp    greece_hospital.dbf  slovakia/
# andorra_school.shx    greece_hospital.prj  slovakia_hospital.cpg
# austria/              greece_hospital.shp  slovakia_hospital.dbf
# austria_hospital.cpg  greece_hospital.shx  slovakia_hospital.prj
# austria_hospital.dbf  greece_school.cpg    slovakia_hospital.shp
# austria_hospital.prj  greece_school.dbf    slovakia_hospital.shx
# austria_hospital.shp  greece_school.prj    slovakia_school.cpg
# austria_hospital.shx  greece_school.shp    slovakia_school.dbf
# austria_school.cpg    greece_school.shx    slovakia_school.prj
# austria_school.dbf    italy/               slovakia_school.shp
# austria_school.prj    italy_hospital.cpg   slovakia_school.shx
# austria_school.shp    italy_hospital.dbf   slovenia/
# austria_school.shx    italy_hospital.prj   slovenia_hospital.cpg
# croatia/              italy_hospital.shp   slovenia_hospital.dbf
# croatia_hospital.cpg  italy_hospital.shx   slovenia_hospital.prj
# croatia_hospital.dbf  italy_school.cpg     slovenia_hospital.shp
# croatia_hospital.prj  italy_school.dbf     slovenia_hospital.shx
# croatia_hospital.shp  italy_school.prj     slovenia_school.cpg
# croatia_hospital.shx  italy_school.shp     slovenia_school.dbf
# croatia_school.cpg    italy_school.shx     slovenia_school.prj
# croatia_school.dbf    monaco/              slovenia_school.shp
# croatia_school.prj    monaco_school.cpg    slovenia_school.shx

# %%
croatia_schools = get_pois_with_landslide_risk('croatia','school')
slovakia_schools = get_pois_with_landslide_risk('slovakia','school')
slovenia_schools = get_pois_with_landslide_risk('slovenia','school')
greece_schools = get_pois_with_landslide_risk('greece','school')
austria_schools = get_pois_with_landslide_risk('austria','school')
italy_schools = get_pois_with_landslide_risk('italy','school')

# %%
croatia_hospitals = get_pois_with_landslide_risk('croatia','hospital')
slovakia_hospitals = get_pois_with_landslide_risk('slovenia','hospital')
slovenia_hospitals = get_pois_with_landslide_risk('slovenia','hospital')
greece_hospitals = get_pois_with_landslide_risk('greece','hospital')
austria_hospitals = get_pois_with_landslide_risk('austria','hospital')
italy_hospitals = get_pois_with_landslide_risk('italy','hospital')

# %%
italy_schools.head()
# Out:
#                                                 name  \
# 0                     Scuola Elementare VII° Circolo
# 1  Istituto tecnico commerciale "Giuseppe Garibal...
# 2  Istituto d'Istruzione Superiore Ruggiero d'Alt...
# 3  Istituto Professionale di Stato per l'Agricolt...
# 4               Scuola Secondaria "Giuseppe Mazzini"
#
#                     geometry  landslide_prob
# 0  POINT (12.50384 37.74178)             0.0
# 1  POINT (12.43623 37.79968)             0.0
# 2  POINT (12.50210 37.72684)             0.0
# 3  POINT (12.51021 37.72866)             0.0
# 4  POINT (12.44164 37.79295)             0.0

# %% [markdown]
# #### 3. Mean landslide frequency for schools & hospitals (at country level)

# %%
dfs_list = [croatia_schools,slovakia_schools,slovenia_schools,greece_schools,austria_schools,italy_schools]
names = ['croatia','slovakia','slovenia','greece','austria','italy']

country_mean_schools = pd.DataFrame({'country': names, 'mean_annual_landslide_frequency': [df.landslide_prob.mean() for df in dfs_list]})
country_mean_schools.sort_values(by='country',inplace=True)
country_mean_schools.reset_index(drop=True,inplace=True)
country_mean_schools
# Out:
#     country  mean_annual_landslide_frequency
# 0   austria                         0.440077
# 1   croatia                         0.211744
# 2    greece                         0.138747
# 3     italy                         0.302300
# 4  slovakia                         0.198642
# 5  slovenia                         0.532775

# %%
dfs_list = [croatia_hospitals,slovakia_hospitals,slovenia_hospitals,greece_hospitals,austria_hospitals,italy_hospitals]
names = ['croatia','slovakia','slovenia','greece','austria','italy']

country_mean_hospitals = pd.DataFrame({'country': names, 'mean_annual_landslide_frequency': [df.landslide_prob.mean() for df in dfs_list]})
country_mean_hospitals.sort_values(by='country',inplace=True)
country_mean_hospitals.reset_index(drop=True,inplace=True)
country_mean_hospitals
# Out:
#     country  mean_annual_landslide_frequency
# 0   austria                         0.449280
# 1   croatia                         0.307820
# 2    greece                         0.246016
# 3     italy                         0.334825
# 4  slovakia                         0.358781
# 5  slovenia                         0.358781

# %%
f,ax = plt.subplots()
width=0.4
height = 0.4
ind=np.arange(len(country_mean_schools))
ax.barh(y= ind, width=country_mean_schools.mean_annual_landslide_frequency,height=height,label='schools')
ax.barh(y= ind + width, width=country_mean_hospitals.mean_annual_landslide_frequency,height=height,label='hospitals')

ax.set(yticks=ind + width, yticklabels=country_mean_schools.country)
ax.legend()

plt.title('Mean annual landslide frequency per country (rainfall-induced)')
plt.show()

# %% [markdown]
# #### 4. Range of values for schools in each country
# This could also be plotted as a probability density function (line chart)

# %%
# histogram to show the range of values

dfs_list = [croatia_schools,slovakia_schools,slovenia_schools,greece_schools,austria_schools,italy_schools]
names = ['croatia','slovakia','slovenia','greece','austria','italy']

f,(axes) = plt.subplots(2,3,figsize=[10,8])

n=0

for df,country_name in zip(dfs_list, names):
    df.landslide_prob.hist(density=True,ax = axes.flatten()[n])
    axes.flatten()[n].set(title = country_name,xlim=[0,2.5],ylim=[0,4])
    n+=1
    
plt.suptitle('Histogram: Rainfall induced landslide hazard frequency (all schools)');

# %%
dfs_list = [croatia_schools,slovakia_schools,slovenia_schools,greece_schools,austria_schools,italy_schools]
names = ['croatia','slovakia','slovenia','greece','austria','italy']

f,(axes) = plt.subplots(2,3,figsize=[10,8])

n=0

for df,country_name in zip(dfs_list, names):
    df.landslide_prob.hist(range=[0.1,df.landslide_prob.max()],density=True,ax = axes.flatten()[n])
    axes.flatten()[n].set(title = country_name,xlim=[0,3],ylim=[0,2.5])
    n+=1
    
plt.suptitle('Histogram: Rainfall induced landslide hazard frequency (schools with non-zero landslide risk)');

# %% [markdown]
# #### 5. Subnational distribution of landslide risk at schools & hospitals

# %%
# get mean landslide frequency by admin unit

def mean_poi_risk_by_ADM(boundaries, poi_gdf,poi_type='school',add_n_pois = True):
    poi_gdf = gpd.sjoin(poi_gdf,boundaries)
    poi_gdf.drop(columns=['index_right'],inplace=True)
    mean_landslide_prob = poi_gdf.groupby('shapeName').mean().sort_values(by='landslide_prob',ascending=False)
    boundaries = boundaries.merge(mean_landslide_prob,left_on='shapeName',right_on = mean_landslide_prob.index)
    boundaries.rename(columns={'landslide_prob':'mean_LS_frequency_{}'.format(poi_type)},inplace=True)
    
    if add_n_pois:
        counts = poi_gdf.shapeName.value_counts()
        counts.name = 'n_pois'
        boundaries = boundaries.merge(counts,left_on='shapeName',right_on=counts.index)
    return(boundaries)

# %%
boundaries_Austria = mean_poi_risk_by_ADM(boundaries_Austria,austria_schools)
boundaries_Croatia = mean_poi_risk_by_ADM(boundaries_Croatia,croatia_schools)
boundaries_Greece = mean_poi_risk_by_ADM(boundaries_Greece,greece_schools)
boundaries_Slovakia = mean_poi_risk_by_ADM(boundaries_Slovakia,slovakia_schools)
boundaries_Slovenia = mean_poi_risk_by_ADM(boundaries_Slovenia,slovenia_schools)
boundaries_Italy = mean_poi_risk_by_ADM(boundaries_Italy,italy_schools)

# %%
dfs_list = [austria_schools,croatia_schools,greece_schools,slovakia_schools,slovenia_schools,italy_schools]
gdfs_list = [boundaries_Austria,boundaries_Croatia,boundaries_Greece,boundaries_Slovakia,boundaries_Slovenia,boundaries_Italy]
names = ['austria','croatia','greece','slovakia','slovenia','italy']
school_numbers = [len(df) for df in dfs_list]

for gdf,country_name,n in zip(gdfs_list, names, school_numbers):
    gdf.plot(column='mean_LS_frequency_school',vmax=1.5,cmap='viridis',legend=True)
    plt.tight_layout()
    plt.title('{}: mean LS frequency per region (n schools = {})'.format(country_name, n));

# %%
boundaries_Austria.drop(columns='geometry').sort_values(by='mean_LS_frequency_school',ascending=False).reset_index(drop=True)
# Out:
#           shapeName  mean_LS_frequency_school  n_pois
# 0             Tirol                  1.150830     570
# 1        Vorarlberg                  0.974639     235
# 2          Salzburg                  0.936599     343
# 3           Kärnten                  0.498345     341
# 4        Steiermark                  0.469694     703
# 5  Niederösterreich                  0.269072    1020
# 6    Oberösterreich                  0.163012     923
# 7        Burgenland                  0.035989     173
# 8              Wien                  0.011558     564

# %%
boundaries_Croatia.drop(columns='geometry').sort_values(by='mean_LS_frequency_school',ascending=False).reset_index(drop=True)
# Out:
#                 shapeName  mean_LS_frequency_school  n_pois
# 0       Dubrovnik-Neretva                  1.164717      33
# 1   Primorje-Gorski Kotar                  0.643668      80
# 2         Krapina-Zagorje                  0.597965      86
# 3          Split-Dalmatia                  0.480084     205
# 4         Po?ega-Slavonia                  0.319084      22
# 5               Lika-Senj                  0.227391      38
# 6            ?ibenik-Knin                  0.217740      50
# 7           Zagreb County                  0.179011     135
# 8                  Istria                  0.170574      57
# 9                Karlovac                  0.110992      58
# 10    Koprivnica-Kri?evci                  0.095436      43
# 11               Vara?din                  0.089400      40
# 12           Zadar County                  0.067597      88
# 13         City of Zagreb                  0.055080     224
# 14   Virovitica-Podravina                  0.020143      41
# 15        Sisak-Moslavina                  0.015615      58
# 16          Brod-Posavina                  0.006728      63
# 17         Vukovar-Syrmia                  0.000000      48
# 18              Me?imurje                  0.000000      47
# 19      Bjelovar-Bilogora                  0.000000      65
# 20         Osijek-Baranja                  0.000000     100

# %%
boundaries_Slovakia.drop(columns='geometry').sort_values(by='mean_LS_frequency_school',ascending=False).reset_index(drop=True)
# Out:
#                    shapeName  mean_LS_frequency_school  n_pois
# 0           Region of ?ilina                  0.524427     335
# 1  Region of Banská Bystrica                  0.273607     283
# 2           Region of Pre?ov                  0.248292     439
# 3          Region of Tren?ín                  0.239884     279
# 4           Region of Ko?ice                  0.168503     373
# 5       Region of Bratislava                  0.036042     325
# 6           Region of Trnava                  0.017727     255
# 7            Region of Nitra                  0.000000     269

# %%
boundaries_Slovenia.drop(columns='geometry').sort_values(by='mean_LS_frequency_school',ascending=False).reset_index(drop=True)
# Out:
#                 shapeName  mean_LS_frequency_school  n_pois
# 0                Zasavska                  1.390975      13
# 1               Gorenjska                  1.172633      53
# 2         Spodnjeposavska                  0.985400      19
# 3                 Gorivka                  0.967627      79
# 4   Jugovzhodna Slovenija                  0.855802      47
# 5                 Koroaka                  0.772258      52
# 6       Notranjsko-kradka                  0.584156      29
# 7               Savinjska                  0.565470     119
# 8       Osrednjeslovenska                  0.440342     193
# 9           Obalno-kra-ka                  0.310879      52
# 10              Podravska                  0.171533     166
# 11               Pomurska                  0.059724      67

# %%
boundaries_Croatia.drop(columns='geometry').sort_values(by='mean_LS_frequency_school',ascending=False).reset_index(drop=True)
# Out:
#                 shapeName  mean_LS_frequency_school  n_pois
# 0       Dubrovnik-Neretva                  1.164717      33
# 1   Primorje-Gorski Kotar                  0.643668      80
# 2         Krapina-Zagorje                  0.597965      86
# 3          Split-Dalmatia                  0.480084     205
# 4         Po?ega-Slavonia                  0.319084      22
# 5               Lika-Senj                  0.227391      38
# 6            ?ibenik-Knin                  0.217740      50
# 7           Zagreb County                  0.179011     135
# 8                  Istria                  0.170574      57
# 9                Karlovac                  0.110992      58
# 10    Koprivnica-Kri?evci                  0.095436      43
# 11               Vara?din                  0.089400      40
# 12           Zadar County                  0.067597      88
# 13         City of Zagreb                  0.055080     224
# 14   Virovitica-Podravina                  0.020143      41
# 15        Sisak-Moslavina                  0.015615      58
# 16          Brod-Posavina                  0.006728      63
# 17         Vukovar-Syrmia                  0.000000      48
# 18              Me?imurje                  0.000000      47
# 19      Bjelovar-Bilogora                  0.000000      65
# 20         Osijek-Baranja                  0.000000     100
